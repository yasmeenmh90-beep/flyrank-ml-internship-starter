# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yasmeenmh90-beep/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os, sys, subprocess

REPO_URL = "https://github.com/yasmeenmh90-beep/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
os.chdir(REPO_DIR)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

# Re-run the pipeline so outputs/model_results.json exists
subprocess.run([sys.executable, "scripts/run_all.py"], check=True)

print("Working dir:", os.getcwd())
# Out:
# Working dir: /content/flyrank-ml-internship-starter

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring. I already ran the starter pipeline in Week 1 and saw a learned model beat a hand-written baseline by roughly 3x (Precision@50: 0.740 vs 0.240). This lane extends that exact workflow — ranking which pages a reviewer should check first — so I can build directly on work I've already validated.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Question: Which pages should be reviewed first for refresh, given limited reviewer time? Decision: which pages a content reviewer spends limited time on first. Action: a reviewer opens the top-ranked pages and decides whether to refresh, expand, or leave them. Cost of a wrong call: reviewers waste time on pages that weren't actually declining, while genuinely weak pages get missed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd, json
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Declining rate:", round((df["trend_direction"] == "down").mean(), 3))
res = json.load(open("outputs/model_results.json"))
print("Baseline Precision@50:", res["baseline"]["baseline_precision_at_50"])
print("Random forest Precision@50:", res["models"]["random_forest"]["precision_at_50"])
# Out:
# Declining rate: 0.542
# Baseline Precision@50: 0.24
# Random forest Precision@50: 0.74

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I can claim a learned ranking outperformed a simple rule on this 30,000-row anonymized starter slice, using client-holdout validation. I cannot claim this generalizes to the full warehouse without re-validating there, and I cannot claim refreshing a page causes recovery — only that this ranking helps prioritize review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
